# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("o9.csv", sep='\t')
data
# Out:
#              id                                              title  \
# 0      11695767                      Работает даже в выходные дни!
# 1      11694888      Семья с ребенком инвалидом осталась без денег
# 2      11694854                                 Заморозили перевод
# 3      11694642                               Горячо приветствуем!
# 4      11694602  Нет возможности закрыть заявку на кредитную карту
# ...         ...                                                ...
# 24686  11560883                                     Благодарность.
# 24687  11560880  Не могу получить страховку по ипотечному договору
# 24688  11560878                                    Возврат средств
# 24689  11560877                             Помогли вернуть деньги
# 24690  11560875             Опять 25! Увольте программистов своих!
#
#                 userName                                               text  \
# 0      user-445919065940  Рекомендую Камкомбанк! Быстрое и вежливое обсл...
# 1      user-230517613460  Добрый день! Муж является клиентом Мтс банка б...
# 2      user-304219058944  9.08.24г. Перевел денежные средства по СПБ меж...
# 3      user-559319057523  Горячо приветствуем! - надпись на баннере одно...
# 4      user-895519057410  08.08.2024 получила смс о том, что мне одобрен...
# ...                  ...                                                ...
# 24686  user-853113556639  Хотела бы выразить свою благодарность Вашему с...
# 24687  user-770018404201  У меня договор ипотеки в банке ВТБ. Жизнь и зд...
# 24688  user-242218404090  Обратился в банк по возврату средств, списанны...
# 24689  user-893018404191  Являюсь давним клиентом банка.01.06 случился н...
# 24690  user-468117880195  <ol>Мария Александровна, здравствуйте! Это сно...
#
#        grade  commentCount  isCountable           dateCreate  \
# 0        5.0             2         True  2024-08-14 12:19:21
# 1        1.0             2         True  2024-08-13 18:01:15
# 2        1.0             1         True  2024-08-13 17:38:32
# 3        1.0             2         True  2024-08-13 15:34:10
# 4        2.0             5         True  2024-08-13 15:14:40
# ...      ...           ...          ...                  ...
# 24686    5.0             0         True  2024-06-10 12:58:52
# 24687    3.0             6         True  2024-06-10 12:57:36
# 24688    5.0             0         True  2024-06-10 12:56:56
# 24689    5.0             0         True  2024-06-10 12:56:32
# 24690    1.0             4         True  2024-06-10 12:55:33
#
#       resolutionIsApproved                                    agentAnswerText  \
# 0                      NaN  Здравствуйте! Спасибо за приятный отклик! Расс...
# 1                     True  Здравствуйте!Взяли отзыв в работу. Приложим ма...
# 2                     True  Здравствуйте!Еще раз приносим извинения за неу...
# 3                     True  Здравствуйте!Возьмем некоторое время для прове...
# 4                     True  Здравствуйте!Взяли отзыв в работу. Как только ...
# ...                    ...                                                ...
# 24686                  NaN  Здравствуйте!Благодарим вас за положительный о...
# 24687                  NaN  Здравствуйте! Ситуация рассматривается в рамка...
# 24688                  NaN  Здравствуйте.Рады, что наша команда смогла реш...
# 24689                  NaN  Приветствуем.Рады, что удалось вернуть деньги!...
# 24690                 True  Добрый день!Рада, что ситуация разрешилась)Все...
#
#        agentId      company  hasDocuments
# 0       193364   kamkombank         False
# 1         6055     mts-bank          True
# 2         2764  gazprombank          True
# 3         6055     mts-bank         False
# 4         6055     mts-bank         False
# ...        ...          ...           ...
# 24686      327          vtb         False
# 24687      327          vtb          True
# 24688   195706          tcs          True
# 24689   195706          tcs          True
# 24690      322     sberbank          True
#
# [24691 rows x 13 columns]

# %%
df = data.drop("id", axis=1).drop("title", axis=1).drop("userName", axis=1).drop("text", axis=1).drop("commentCount", axis=1).drop("isCountable", axis=1).drop("dateCreate", axis=1).drop("resolutionIsApproved", axis=1).drop("agentAnswerText", axis=1).drop("agentId", axis=1).drop("hasDocuments", axis=1)
df
# Out:
#        grade      company
# 0        5.0   kamkombank
# 1        1.0     mts-bank
# 2        1.0  gazprombank
# 3        1.0     mts-bank
# 4        2.0     mts-bank
# ...      ...          ...
# 24686    5.0          vtb
# 24687    3.0          vtb
# 24688    5.0          tcs
# 24689    5.0          tcs
# 24690    1.0     sberbank
#
# [24691 rows x 2 columns]

# %%
sns.pairplot(df, hue="company")

# %%
sns.boxplot(df, x="grade", y="grade", hue="company")
# Out:
# <Axes: xlabel='grade', ylabel='grade'>
